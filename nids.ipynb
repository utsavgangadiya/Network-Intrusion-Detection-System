# %%
# Import Libraries
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

# Load Dataset
df = pd.read_csv("cicids2017_cleaned.csv")

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %%
print("Shape of Dataset:", df.shape)

print(f"\nRows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# Shape of Dataset: (2520751, 53)
#
# Rows    : 2520751
# Columns : 53

# %%
df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  \
# 0                22        1266342                 41
# 1                22        1319353                 41
# 2                22            160                  1
# 3                22        1303488                 41
# 4             35396             77                  1
#
#    Total Length of Fwd Packets  Fwd Packet Length Max  Fwd Packet Length Min  \
# 0                         2664                    456                      0
# 1                         2664                    456                      0
# 2                            0                      0                      0
# 3                         2728                    456                      0
# 4                            0                      0                      0
#
#    Fwd Packet Length Mean  Fwd Packet Length Std  Bwd Packet Length Max  \
# 0               64.975610             109.864573                    976
# 1               64.975610             109.864573                    976
# 2                0.000000               0.000000                      0
# 3               66.536585             110.129945                    976
# 4                0.000000               0.000000                      0
#
#    Bwd Packet Length Min  Bwd Packet Length Mean  Bwd Packet Length Std  \
# 0                      0              158.045455             312.675250
# 1                      0              158.045455             312.675250
# 2                      0                0.000000               0.000000
# 3                      0              157.952381             319.121427
# 4                      0                0.000000               0.000000
#
#    Flow Bytes/s  Flow Packets/s  Flow IAT Mean   Flow IAT Std  Flow IAT Max  \
# 0   7595.104640       67.122468    15075.50000  104051.399700        948537
# 1   7289.936810       64.425518    15706.58333  104861.870100        955790
# 2      0.000000    12500.000000      160.00000       0.000000           160
# 3   7182.267884       63.675308    15896.19512  106554.899000        956551
# 4      0.000000    38961.038960       38.50000      14.849242            49
#
#    Flow IAT Min  Fwd IAT Total  Fwd IAT Mean  Fwd IAT Std  Fwd IAT Max  \
# 0             0        1266342     31658.550  159355.2595       996324
# 1             1        1319353     32983.825  159247.9008       996423
# 2           160              0         0.000       0.0000            0
# 3             0        1303488     32587.200  160397.0499       997357
# 4            28              0         0.000       0.0000            0
#
#    Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  Bwd IAT Std  Bwd IAT Max  \
# 0            2         317671   7387.697674  19636.44809       104616
# 1            1         363429   8451.837209  21337.26261       104815
# 2            0              0      0.000000      0.00000            0
# 3            1         346851   8459.780488  23962.23892       138295
# 4            0             49     49.000000      0.00000           49
#
#    Bwd IAT Min  Fwd Header Length  Bwd Header Length  Fwd Packets/s  \
# 0            1               1328               1424      32.376720
# 1            1               1328               1424      31.075838
# 2            0                 32                 32    6250.000000
# 3            0               1328               1360      31.454068
# 4           49                 32                 64   12987.012990
#
#    Bwd Packets/s  Min Packet Length  Max Packet Length  Packet Length Mean  \
# 0      34.745748                  0                976          111.837209
# 1      33.349680                  0                976          111.837209
# 2    6250.000000                  0                  0            0.000000
# 3      32.221240                  0                976          111.452381
# 4   25974.025970                  0                  0            0.000000
#
#    Packet Length Std  Packet Length Variance  FIN Flag Count  PSH Flag Count  \
# 0         239.686848             57449.78495               0               1
# 1         239.686848             57449.78495               0               1
# 2           0.000000                 0.00000               0               0
# 3         241.642791             58391.23867               0               1
# 4           0.000000                 0.00000               0               0
#
#    ACK Flag Count  Average Packet Size  Subflow Fwd Bytes  \
# 0               0           113.152941               2664
# 1               0           113.152941               2664
# 2               1             0.000000                  0
# 3               0           112.795181               2728
# 4               1             0.000000                  0
#
#    Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# 0                   29200                      243                24
# 1                   29200                      243                24
# 2                     290                      243                 0
# 3                   29200                      243                24
# 4                     243                      290                 0
#
#    min_seg_size_forward  Active Mean  Active Max  Active Min  Idle Mean  \
# 0                    32          0.0           0           0        0.0
# 1                    32          0.0           0           0        0.0
# 2                    32          0.0           0           0        0.0
# 3                    32          0.0           0           0        0.0
# 4                    32          0.0           0           0        0.0
#
#    Idle Max  Idle Min     Attack Type
# 0         0         0  Normal Traffic
# 1         0         0  Normal Traffic
# 2         0         0  Normal Traffic
# 3         0         0  Normal Traffic
# 4         0         0  Normal Traffic

# %%
print(df.columns.tolist())
# Out:
# ['Destination Port', 'Flow Duration', 'Total Fwd Packets', 'Total Length of Fwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max', 'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count', 'PSH Flag Count', 'ACK Flag Count', 'Average Packet Size', 'Subflow Fwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'Active Mean', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Max', 'Idle Min', 'Attack Type']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2520751 entries, 0 to 2520750
# Data columns (total 53 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Length of Fwd Packets  int64
#  4   Fwd Packet Length Max        int64
#  5   Fwd Packet Length Min        int64
#  6   Fwd Packet Length Mean       float64
#  7   Fwd Packet Length Std        float64
#  8   Bwd Packet Length Max        int64
#  9   Bwd Packet Length Min        int64
#  10  Bwd Packet Length Mean       float64
#  11  Bwd Packet Length Std        float64
#  12  Flow Bytes/s                 float64
#  13  Flow Packets/s               float64
#  14  Flow IAT Mean                float64
#  15  Flow IAT Std                 float64
#  16  Flow IAT Max                 int64
#  17  Flow IAT Min                 int64
#  18  Fwd IAT Total                int64
#  19  Fwd IAT Mean                 float64
#  20  Fwd IAT Std                  float64
#  21  Fwd IAT Max                  int64
#  22  Fwd IAT Min                  int64
#  23  Bwd IAT Total                int64
#  24  Bwd IAT Mean                 float64
#  25  Bwd IAT Std                  float64
#  26  Bwd IAT Max                  int64
#  27  Bwd IAT Min                  int64
#  28  Fwd Header Length            int64
#  29  Bwd Header Length            int64
#  30  Fwd Packets/s                float64
#  31  Bwd Packets/s                float64
#  32  Min Packet Length            int64
#  33  Max Packet Length            int64
#  34  Packet Length Mean           float64
#  35  Packet Length Std            float64
#  36  Packet Length Variance       float64
#  37  FIN Flag Count               int64
#  38  PSH Flag Count               int64
#  39  ACK Flag Count               int64
#  40  Average Packet Size          float64
#  41  Subflow Fwd Bytes            int64
#  42  Init_Win_bytes_forward       int64
#  43  Init_Win_bytes_backward      int64
#  44  act_data_pkt_fwd             int64
#  45  min_seg_size_forward         int64
#  46  Active Mean                  float64
#  47  Active Max                   int64
#  48  Active Min                   int64
#  49  Idle Mean                    float64
#  50  Idle Max                     int64
#  51  Idle Min                     int64
#  52  Attack Type                  str
# dtypes: float64(20), int64(32), str(1)
# memory usage: 1019.3 MB

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows :", duplicates)
# Out:
# Duplicate Rows : 161

# %%
df_cleaned = df.drop_duplicates()

# %%
print(df["Attack Type"].value_counts())
# Out:
# Attack Type
# Normal Traffic    2095057
# DoS                193745
# DDoS               128014
# Port Scanning       90694
# Brute Force          9150
# Web Attacks          2143
# Bots                 1948
# Name: count, dtype: int64

# %%
print(df["Attack Type"].value_counts(normalize=True) * 100)
# Out:
# Attack Type
# Normal Traffic    83.112414
# DoS                7.686003
# DDoS               5.078407
# Port Scanning      3.597896
# Brute Force        0.362987
# Web Attacks        0.085014
# Bots               0.077279
# Name: proportion, dtype: float64

# %%
numeric_columns = df.select_dtypes(include=np.number).columns

print("Total Numeric Columns :", len(numeric_columns))
print(numeric_columns)
# Out:
# Total Numeric Columns : 52
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Length of Fwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd Header Length', 'Bwd Header Length',
#        'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length',
#        'Max Packet Length', 'Packet Length Mean', 'Packet Length Std',
#        'Packet Length Variance', 'FIN Flag Count', 'PSH Flag Count',
#        'ACK Flag Count', 'Average Packet Size', 'Subflow Fwd Bytes',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'Active Mean', 'Active Max', 'Active Min',
#        'Idle Mean', 'Idle Max', 'Idle Min'],
#       dtype='str')

# %%
categorical_columns = df.select_dtypes(include="object").columns

print("Categorical Columns :", categorical_columns)
# Out:
# Categorical Columns : Index(['Attack Type'], dtype='str')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7588\1073553164.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include="object").columns

# %%
print("Memory Usage")

print(df.memory_usage(deep=True))
# Out:
# Memory Usage
# Index                                132
# Destination Port                20166008
# Flow Duration                   20166008
# Total Fwd Packets               20166008
# Total Length of Fwd Packets     20166008
# Fwd Packet Length Max           20166008
# Fwd Packet Length Min           20166008
# Fwd Packet Length Mean          20166008
# Fwd Packet Length Std           20166008
# Bwd Packet Length Max           20166008
# Bwd Packet Length Min           20166008
# Bwd Packet Length Mean          20166008
# Bwd Packet Length Std           20166008
# Flow Bytes/s                    20166008
# Flow Packets/s                  20166008
# Flow IAT Mean                   20166008
# Flow IAT Std                    20166008
# Flow IAT Max                    20166008
# Flow IAT Min                    20166008
# Fwd IAT Total                   20166008
# Fwd IAT Mean                    20166008
# Fwd IAT Std                     20166008
# Fwd IAT Max                     20166008
# Fwd IAT Min                     20166008
# Bwd IAT Total                   20166008
# Bwd IAT Mean                    20166008
# Bwd IAT Std                     20166008
# Bwd IAT Max                     20166008
# Bwd IAT Min                     20166008
# Fwd Header Length               20166008
# Bwd Header Length               20166008
# Fwd Packets/s                   20166008
# Bwd Packets/s                   20166008
# Min Packet Length               20166008
# Max Packet Length               20166008
# Packet Length Mean              20166008
# Packet Length Std               20166008
# Packet Length Variance          20166008
# FIN Flag Count                  20166008
# PSH Flag Count                  20166008
# ACK Flag Count                  20166008
# Average Packet Size             20166008
# Subflow Fwd Bytes               20166008
# Init_Win_bytes_forward          20166008
# Init_Win_bytes_backward         20166008
# act_data_pkt_fwd                20166008
# min_seg_size_forward            20166008
# Active Mean                     20166008
# Active Max                      20166008
# Active Min                      20166008
# Idle Mean                       20166008
# Idle Max                        20166008
# Idle Min                        20166008
# Attack Type                    155251925
# dtype: int64

# %%
print("=" * 50)
print("DATASET SUMMARY")
print("=" * 50)

print(f"Rows                : {df.shape[0]}")
print(f"Columns             : {df.shape[1]}")
print(f"Duplicate Rows      : {df.duplicated().sum()}")
print(f"Missing Values      : {df.isnull().sum().sum()}")
print(f"Numeric Columns     : {len(df.select_dtypes(include=np.number).columns)}")
print(f"Categorical Columns : {len(df.select_dtypes(include='object').columns)}")
print("\nTarget Classes:")
print(df["Attack Type"].value_counts())

print("=" * 50)
# Out:
# ==================================================
# DATASET SUMMARY
# ==================================================
# Rows                : 2520751
# Columns             : 53
# Duplicate Rows      : 161
# Missing Values      : 0
# Numeric Columns     : 52
# Categorical Columns : 1
#
# Target Classes:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7588\981354196.py:10: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print(f"Categorical Columns : {len(df.select_dtypes(include='object').columns)}")
# Attack Type
# Normal Traffic    2095057
# DoS                193745
# DDoS               128014
# Port Scanning       90694
# Brute Force          9150
# Web Attacks          2143
# Bots                 1948
# Name: count, dtype: int64
# ==================================================

# %%
numeric_df = df.select_dtypes(include=np.number)

inf_values = np.isinf(numeric_df).sum().sum()

print("Total Infinite Values :", inf_values)
# Out:
# Total Infinite Values : 0

# %%
before = df.shape[0]

df.dropna(inplace=True)

after = df.shape[0]

print("Rows Removed :", before-after)
# Out:
# Rows Removed : 0

# %%
before = df.shape[0]

df.drop_duplicates(inplace=True)

after = df.shape[0]

print("Duplicates Removed :", before-after)
# Out:
# Duplicates Removed : 161

# %%
df.reset_index(drop=True, inplace=True)

# %%
print("="*50)
print("AFTER CLEANING")
print("="*50)

print("Shape :", df.shape)

print("Missing Values :", df.isnull().sum().sum())

print("Duplicate Rows :", df.duplicated().sum())

print("Infinite Values :",
      np.isinf(df.select_dtypes(include=np.number)).sum().sum())
# Out:
# ==================================================
# AFTER CLEANING
# ==================================================
# Shape : (2520590, 53)
# Missing Values : 0
# Duplicate Rows : 0
# Infinite Values : 0

# %%
df = pd.read_csv("cicids2017_final_cleaned.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
import os
os.makedirs("charts", exist_ok=True)

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(10,6))

sns.countplot(
    y=df["Attack Type"],
    order=df["Attack Type"].value_counts().index
)

plt.title("Attack Type Distribution")
plt.tight_layout()

plt.savefig("charts/attack_distribution.png", dpi=300)

plt.show()

# %%
plt.figure(figsize=(8,8))

df["Attack Type"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")
plt.title("Attack Type Percentage")

plt.savefig("charts/attack_pie_chart.png", dpi=300)

plt.show()

# %%
plt.figure(figsize=(20,18))

corr = df.select_dtypes(include=np.number).corr()

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Heatmap")

plt.savefig("charts/correlation_heatmap.png", dpi=300)

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.histplot(df["Flow Duration"], bins=30)

plt.title("Flow Duration Distribution")

plt.savefig("charts/flow_duration_histogram.png", dpi=300)

plt.show()

# %%
corr = df.select_dtypes(include=np.number).corr()

target_corr = corr["Packet Length Mean"].sort_values(ascending=False)

plt.figure(figsize=(8,10))

target_corr.head(15).plot(kind="barh")

plt.title("Top Correlated Features")

plt.tight_layout()

plt.savefig("charts/top_correlations.png", dpi=300)

plt.show()

# %%
summary = pd.DataFrame({
    "Count": df["Attack Type"].value_counts(),
    "Percentage": round(df["Attack Type"].value_counts(normalize=True)*100,2)
})

print(summary)

summary.to_csv("charts/attack_summary.csv")
# Out:
#                   Count  Percentage
# Attack Type
# Normal Traffic  1325656       85.22
# DDoS             128014        8.23
# Port Scanning     90694        5.83
# Brute Force        9150        0.59
# Web Attacks        2143        0.14
# Bots                  2        0.00

# %% [markdown]
# Data Preprocessing

# %%
import joblib

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
os.makedirs("models", exist_ok=True)

# %%
import psutil

memory = psutil.virtual_memory()

print(f"Total RAM     : {memory.total / (1024**3):.2f} GB")
print(f"Available RAM : {memory.available / (1024**3):.2f} GB")
print(f"Used RAM      : {memory.used / (1024**3):.2f} GB")
print(f"RAM Usage     : {memory.percent}%")
# Out:
# Total RAM     : 7.86 GB
# Available RAM : 1.18 GB
# Used RAM      : 6.67 GB
# RAM Usage     : 84.9%

# %%
from sklearn.model_selection import train_test_split

_, df_sample = train_test_split(
    df,
    test_size=500000,
    stratify=df["Attack Type"],
    random_state=42
)

df_sample.to_csv("cicids2017_sample.csv", index=False)

# %%
df = pd.read_csv("cicids2017_sample.csv")

print(df.shape)
# Out:
# (500000, 53)

# %%
import joblib

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()

df["Attack Type"] = le.fit_transform(df["Attack Type"])

# %%
joblib.dump(le, "models/label_encoder.pkl")
# Out:
# ['models/label_encoder.pkl']

# %%
X = df.drop("Attack Type", axis=1)

y = df["Attack Type"]

# %%
print(y.value_counts())
# Out:
# Attack Type
# 3    426075
# 2     41144
# 4     29150
# 1      2941
# 5       689
# 0         1
# Name: count, dtype: int64

# %%
# Keep only classes having at least 2 samples
counts = df["Attack Type"].value_counts()

valid_classes = counts[counts >= 2].index

df = df[df["Attack Type"].isin(valid_classes)]

print(df["Attack Type"].value_counts())
# Out:
# Attack Type
# 3    426075
# 2     41144
# 4     29150
# 1      2941
# 5       689
# Name: count, dtype: int64

# %%
print(le.classes_)
# Out:
# ['Bots' 'Brute Force' 'DDoS' 'DoS' 'Normal Traffic' 'Port Scanning'
#  'Web Attacks']

# %%
X = df.drop("Attack Type", axis=1)
y = df["Attack Type"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
import joblib
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Model 1 — Logistic Regression

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

lr = LogisticRegression(
    max_iter=1000,
    random_state=42
)

lr.fit(X_train_scaled, y_train)

y_pred_lr = lr.predict(X_test_scaled)

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_lr))

print(classification_report(y_test, y_pred_lr))
# Out:
# Accuracy : 0.97507
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        77
#            1       0.99      0.78      0.87       363
#            2       0.99      0.96      0.97      5078
#            3       0.99      0.93      0.95      7686
#            4       0.99      0.98      0.99     83113
#            5       0.73      0.99      0.84      3598
#            6       0.00      0.00      0.00        85
#
#     accuracy                           0.98    100000
#    macro avg       0.67      0.66      0.66    100000
# weighted avg       0.98      0.98      0.98    100000
# c:\Users\Lenovo\AppData\Local\Python\pythoncore-3.13-64\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Lenovo\AppData\Local\Python\pythoncore-3.13-64\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Lenovo\AppData\Local\Python\pythoncore-3.13-64\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
joblib.dump(lr, "models/logistic_regression.pkl")
joblib.dump(scaler, "models/scaler.pkl")
# Out:
# ['models/scaler.pkl']

# %% [markdown]
# Model 2 — Decision Tree

# %%
dt = DecisionTreeClassifier(
    random_state=42
)

dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred_dt))

print(classification_report(y_test, y_pred_dt))

joblib.dump(dt, "models/decision_tree.pkl")
# Out:
# Accuracy : 0.99831
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.77        77
#            1       1.00      0.99      1.00       363
#            2       1.00      1.00      1.00      5078
#            3       1.00      1.00      1.00      7686
#            4       1.00      1.00      1.00     83113
#            5       0.99      0.99      0.99      3598
#            6       0.95      0.93      0.94        85
#
#     accuracy                           1.00    100000
#    macro avg       0.96      0.95      0.96    100000
# weighted avg       1.00      1.00      1.00    100000
# ['models/decision_tree.pkl']

# %% [markdown]
# Model 3 — Random Forest

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred_rf))

print(classification_report(y_test, y_pred_rf))

joblib.dump(rf, "models/random_forest.pkl")
# Out:
# Accuracy : 0.99825
#               precision    recall  f1-score   support
#
#            0       0.81      0.66      0.73        77
#            1       1.00      0.99      1.00       363
#            2       1.00      1.00      1.00      5078
#            3       1.00      1.00      1.00      7686
#            4       1.00      1.00      1.00     83113
#            5       0.99      0.99      0.99      3598
#            6       0.96      0.93      0.95        85
#
#     accuracy                           1.00    100000
#    macro avg       0.97      0.94      0.95    100000
# weighted avg       1.00      1.00      1.00    100000
# ['models/random_forest.pkl']

# %% [markdown]
# Model 4 — XGBoost

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.3.0-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\Users\Lenovo\AppData\Local\Python\pythoncore-3.13-64\Lib\site-packages (from xgboost) (2.5.1)
# Requirement already satisfied: scipy in c:\Users\Lenovo\AppData\Local\Python\pythoncore-3.13-64\Lib\site-packages (from xgboost) (1.18.0)
# Downloading xgboost-3.3.0-py3-none-win_amd64.whl (69.5 MB)
#    ---------------------------------------- 0.0/69.5 MB ? eta -:--:--
#     --------------------------------------- 1.6/69.5 MB 12.8 MB/s eta 0:00:06
#    --- ------------------------------------ 5.5/69.5 MB 13.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 9.2/69.5 MB 13.9 MB/s eta 0:00:05
#    ------- -------------------------------- 12.8/69.5 MB 14.0 MB/s eta 0:00:05
#    --------- ------------------------------ 15.7/69.5 MB 14.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 18.6/69.5 MB 13.4 MB/s eta 0:00:04
#    ------------ --------------------------- 21.0/69.5 MB 13.0 MB/s eta 0:00:04
#    ------------- -------------------------- 23.9/69.5 MB 12.9 MB/s eta 0:00:04
#    --------------- ------------------------ 27.0/69.5 MB 12.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 29.6/69.5 MB 12.6 MB/s eta 0:00:04
#    ------------------ --------------------- 32.2/69.5 MB 12.5 MB/s eta 0:00:03
#    -------------------- ------------------- 35.1/69.5 MB 12.5 MB/s eta 0:00:03
#    --------------------- ------------------ 38.0/69.5 MB 12.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 41.2/69.5 MB 12.5 MB/s eta 0:00:03
#    ------------------------- -------------- 44.0/69.5 MB 12.5 MB/s eta 0:00:03
#    -------------------------- ------------- 46.9/69.5 MB 12.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 49.8/69.5 MB 12.6 MB/s eta 0:00:02
#    ------------------------------ --------- 52.7/69.5 MB 12.6 MB/s eta 0:00:02
#    -------------------------------- ------- 55.8/69.5 MB 12.7 MB/s eta 0:00:02
#    --------------------------------- ------ 59.0/69.5 MB 12.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 62.4/69.5 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- -- 65.8/69.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  68.9/69.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.5 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 69.5/69.5 MB 11.8 MB/s  0:00:05
# Installing collected packages: xgboost
# Successfully installed xgboost-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(
    random_state=42,
    tree_method="hist",
    eval_metric="mlogloss"
)

xgb.fit(X_train, y_train)

y_pred_xgb = xgb.predict(X_test)

print("Accuracy :", accuracy_score(y_test, y_pred_xgb))

print(classification_report(y_test, y_pred_xgb))

joblib.dump(xgb, "models/xgboost.pkl")
# Out:
# Accuracy : 0.99898
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81        77
#            1       1.00      1.00      1.00       363
#            2       1.00      1.00      1.00      5078
#            3       1.00      1.00      1.00      7686
#            4       1.00      1.00      1.00     83113
#            5       0.99      1.00      0.99      3598
#            6       0.96      0.94      0.95        85
#
#     accuracy                           1.00    100000
#    macro avg       0.97      0.96      0.96    100000
# weighted avg       1.00      1.00      1.00    100000
# ['models/xgboost.pkl']

# %%
results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy": [
        accuracy_score(y_test, y_pred_lr),
        accuracy_score(y_test, y_pred_dt),
        accuracy_score(y_test, y_pred_rf),
        accuracy_score(y_test, y_pred_xgb)
    ],
    "Precision": [
        precision_score(y_test, y_pred_lr, average="weighted"),
        precision_score(y_test, y_pred_dt, average="weighted"),
        precision_score(y_test, y_pred_rf, average="weighted"),
        precision_score(y_test, y_pred_xgb, average="weighted")
    ],
    "Recall": [
        recall_score(y_test, y_pred_lr, average="weighted"),
        recall_score(y_test, y_pred_dt, average="weighted"),
        recall_score(y_test, y_pred_rf, average="weighted"),
        recall_score(y_test, y_pred_xgb, average="weighted")
    ],
    "F1 Score": [
        f1_score(y_test, y_pred_lr, average="weighted"),
        f1_score(y_test, y_pred_dt, average="weighted"),
        f1_score(y_test, y_pred_rf, average="weighted"),
        f1_score(y_test, y_pred_xgb, average="weighted")
    ]
})

print(results)

results.to_csv("models/model_comparison.csv", index=False)
# Out:
# c:\Users\Lenovo\AppData\Local\Python\pythoncore-3.13-64\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#                  Model  Accuracy  Precision   Recall  F1 Score
# 0  Logistic Regression   0.97507   0.976950  0.97507  0.975118
# 1        Decision Tree   0.99831   0.998298  0.99831  0.998303
# 2        Random Forest   0.99825   0.998221  0.99825  0.998229
# 3              XGBoost   0.99898   0.998981  0.99898  0.998979

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred_lr,
    cmap="Blues"
)

plt.title("Logistic Regression")
plt.savefig("charts/lr_confusion_matrix.png", dpi=300)
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_test,
    y_pred_xgb,
    output_dict=True
)

report = pd.DataFrame(report).transpose()

report.to_csv(
    "charts/xgboost_report.csv"
)

# %%
import pandas as pd
import matplotlib.pyplot as plt

importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": xgb.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(20)
# Out:
#                         Feature  Importance
# 49                    Idle Mean    0.461849
# 24                 Bwd IAT Mean    0.109950
# 11        Bwd Packet Length Std    0.102947
# 44             act_data_pkt_fwd    0.051083
# 10       Bwd Packet Length Mean    0.039895
# 29            Bwd Header Length    0.034275
# 27                  Bwd IAT Min    0.027675
# 12                 Flow Bytes/s    0.022704
# 7         Fwd Packet Length Std    0.022189
# 40          Average Packet Size    0.018784
# 3   Total Length of Fwd Packets    0.017542
# 4         Fwd Packet Length Max    0.015757
# 38               PSH Flag Count    0.012753
# 42       Init_Win_bytes_forward    0.011023
# 28            Fwd Header Length    0.010367
# 43      Init_Win_bytes_backward    0.006354
# 33            Max Packet Length    0.005298
# 22                  Fwd IAT Min    0.004368
# 39               ACK Flag Count    0.003762
# 0              Destination Port    0.003727

# %%
plt.figure(figsize=(10,8))

plt.barh(
    importance.head(20)["Feature"],
    importance.head(20)["Importance"]
)

plt.gca().invert_yaxis()

plt.title("Top 20 Important Features")

plt.tight_layout()

plt.savefig(
    "charts/feature_importance.png",
    dpi=300
)

plt.show()

# %%
import joblib

joblib.dump(
    xgb,
    "models/network_intrusion_detector.pkl"
)
# Out:
# ['models/network_intrusion_detector.pkl']
